# %%
# !git clone https://github.com/thuml/Time-Series-Library.git
# Out:
# fatal: destination path 'Time-Series-Library' already exists and is not an empty directory.

# %%
# %cd /content/Time-Series-Library
# Out:
# /content/Time-Series-Library

# %%
# !mkdir -p ./dataset/illness

# %%
# !pip install einops local-attention matplotlib numpy==1.23.5 pandas patool scikit-learn scipy==1.10.1 sktime sympy torch==1.13.1 tqdm pywavelets "dask[dataframe]"
# Out:
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (0.8.1)
# Requirement already satisfied: local-attention in /usr/local/lib/python3.11/dist-packages (1.10.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: numpy==1.23.5 in /usr/local/lib/python3.11/dist-packages (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: patool in /usr/local/lib/python3.11/dist-packages (4.0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: scipy==1.10.1 in /usr/local/lib/python3.11/dist-packages (1.10.1)
# Requirement already satisfied: sktime in /usr/local/lib/python3.11/dist-packages (0.37.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (1.13.1)
# Requirement already satisfied: torch==1.13.1 in /usr/local/lib/python3.11/dist-packages (1.13.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: pywavelets in /usr/local/lib/python3.11/dist-packages (1.8.0)
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.11/dist-packages (2024.8.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==1.13.1) (4.13.2)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.11/dist-packages (from torch==1.13.1) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.11/dist-packages (from torch==1.13.1) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.11/dist-packages (from torch==1.13.1) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.11/dist-packages (from torch==1.13.1) (11.7.99)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1) (75.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1) (0.45.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: scikit-base<0.13.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from sktime) (0.12.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy) (1.3.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (2025.3.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (8.6.1)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (1.1.11)
# Requirement already satisfied: pyarrow>=7.0.0 in /usr/local/lib/python3.11/dist-packages (from dask-expr<1.2,>=1.1->dask[dataframe]) (18.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=4.13.0->dask[dataframe]) (3.21.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask[dataframe]) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !pip install reformer-pytorch
# Out:
# Collecting reformer-pytorch
#   Using cached reformer_pytorch-1.4.4-py3-none-any.whl.metadata (764 bytes)
# Collecting axial-positional-embedding>=0.1.0 (from reformer-pytorch)
#   Using cached axial_positional_embedding-0.3.12-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from reformer-pytorch) (0.8.1)
# Requirement already satisfied: local-attention in /usr/local/lib/python3.11/dist-packages (from reformer-pytorch) (1.10.0)
# Collecting product-key-memory (from reformer-pytorch)
#   Using cached product_key_memory-0.2.11-py3-none-any.whl.metadata (717 bytes)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from reformer-pytorch) (1.13.1)
# Collecting torch (from reformer-pytorch)
#   Using cached torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->reformer-pytorch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->reformer-pytorch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->reformer-pytorch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->reformer-pytorch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->reformer-pytorch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->reformer-pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->reformer-pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->reformer-pytorch) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->reformer-pytorch)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->reformer-pytorch)
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->reformer-pytorch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->reformer-pytorch) (10.3.5.147)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->reformer-pytorch)
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->reformer-pytorch)
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->reformer-pytorch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->reformer-pytorch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->reformer-pytorch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->reformer-pytorch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->reformer-pytorch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->reformer-pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->reformer-pytorch) (1.3.0)
# Collecting colt5-attention>=0.10.14 (from product-key-memory->reformer-pytorch)
#   Using cached CoLT5_attention-0.11.1-py3-none-any.whl.metadata (737 bytes)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from colt5-attention>=0.10.14->product-key-memory->reformer-pytorch) (24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->reformer-pytorch) (3.0.2)
# Using cached reformer_pytorch-1.4.4-py3-none-any.whl (16 kB)
# Using cached axial_positional_embedding-0.3.12-py3-none-any.whl (6.7 kB)
# Using cached torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl (766.7 MB)
# Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# Using cached product_key_memory-0.2.11-py3-none-any.whl (6.5 kB)
# Using cached CoLT5_attention-0.11.1-py3-none-any.whl (18 kB)
# Installing collected packages: nvidia-cusparse-cu12, nvidia-cublas-cu12, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch, axial-positional-embedding, colt5-attention, product-key-memory, reformer-pytorch
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1
#     Uninstalling torch-1.13.1:
#       Successfully uninstalled torch-1.13.1
# Successfully installed axial-positional-embedding-0.3.12 colt5-attention-0.11.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 product-key-memory-0.2.11 reformer-pytorch-1.4.4 torch-2.6.0

# %% [markdown]
# # std of noise = 0.01

# %%
# !python -u run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/illness/ \
  --data_path national_illness.csv \
  --model_id ECL_96_96 \
  --model TimesNet \
  --data custom \
  --features M \
  --seq_len 60 \
  --label_len 48 \
  --pred_len 24 \
  --e_layers 2 \
  --d_layers 1 \
  --factor 3 \
  --enc_in 7 \
  --dec_in 7 \
  --c_out 7 \
  --d_model 256 \
  --d_ff 512 \
  --top_k 5 \
  --des 'NoiseTest_std001'\
  --itr 1
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ECL_96_96           Model:              TimesNet
#
# Data Loader
#   Data:               custom              Root Path:          ./dataset/illness/
#   Data Path:          national_illness.csvFeatures:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            60                  Label Len:          48
#   Pred Len:           24                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            256
#   n heads:            8                   e layers:           2
#   d layers:           1                   d FF:               512
#   Moving Avg:         25                  Factor:             3
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       10                  Batch Size:         32
#   Patience:           3                   Learning Rate:      0.0001
#   Des:                NoiseTest_std001    Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# >>>>>>>start training : long_term_forecast_ECL_96_96_TimesNet_custom_ftM_sl60_ll48_pl24_dm256_nh8_el2_dl1_df512_expand2_dc4_fc3_ebtimeF_dtTrue_NoiseTest_std001_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 593
# val 74
# test 170
# Epoch: 1 cost time: 5.7139387130737305
# Epoch: 1, Steps: 19 | Train Loss: 0.6893893 Vali Loss: 0.3575294 Test Loss: 2.6204586
# Validation loss decreased (inf --> 0.357529).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 4.410186052322388
# Epoch: 2, Steps: 19 | Train Loss: 0.4809290 Vali Loss: 0.3328673 Test Loss: 2.7744815
# Validation loss decreased (0.357529 --> 0.332867).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 4.409980535507202
# Epoch: 3, Steps: 19 | Train Loss: 0.3952466 Vali Loss: 0.3112910 Test Loss: 2.5590391
# Validation loss decreased (0.332867 --> 0.311291).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 4.4231555461883545
# Epoch: 4, Steps: 19 | Train Loss: 0.3552491 Vali Loss: 0.2772477 Test Loss: 2.8003769
# Validation loss decreased (0.311291 --> 0.277248).  Saving model ...
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 4.390764474868774
# Epoch: 5, Steps: 19 | Train Loss: 0.3186142 Vali Loss: 0.2794870 Test Loss: 2.7764270
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 4.398604393005371
# Epoch: 6, Steps: 19 | Train Loss: 0.3135583 Vali Loss: 0.2745975 Test Loss: 3.0093040
# Validation loss decreased (0.277248 --> 0.274597).  Saving model ...
# Updating learning rate to 3.125e-06
# Epoch: 7 cost time: 4.3802430629730225
# Epoch: 7, Steps: 19 | Train Loss: 0.3066273 Vali Loss: 0.3321414 Test Loss: 2.9044800
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.5625e-06
# Epoch: 8 cost time: 4.370217800140381
# Epoch: 8, Steps: 19 | Train Loss: 0.3017934 Vali Loss: 0.2823142 Test Loss: 2.9417617
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 7.8125e-07
# Epoch: 9 cost time: 4.395966529846191
# Epoch: 9, Steps: 19 | Train Loss: 0.3058206 Vali Loss: 0.2753448 Test Loss: 2.9467442
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : long_term_forecast_ECL_96_96_TimesNet_custom_ftM_sl60_ll48_pl24_dm256_nh8_el2_dl1_df512_expand2_dc4_fc3_ebtimeF_dtTrue_NoiseTest_std001_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 170
# test shape: (170, 24, 7) (170, 24, 7)
# test shape: (170, 24, 7) (170, 24, 7)
# mse:2.3151752948760986, mae:0.9773611426353455, dtw:Not calculated

# %% [markdown]
# # std of noise = 0.1

# %%
# !python -u run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/illness/ \
  --data_path national_illness.csv \
  --model_id ECL_96_96 \
  --model TimesNet \
  --data custom \
  --features M \
  --seq_len 60 \
  --label_len 48 \
  --pred_len 24 \
  --e_layers 2 \
  --d_layers 1 \
  --factor 3 \
  --enc_in 7 \
  --dec_in 7 \
  --c_out 7 \
  --d_model 256 \
  --d_ff 512 \
  --top_k 5 \
  --des 'NoiseTest_std01'\
  --add_noise \
  --noise_std 0.1\
  --itr 1
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ECL_96_96           Model:              TimesNet
#
# Data Loader
#   Data:               custom              Root Path:          ./dataset/illness/
#   Data Path:          national_illness.csvFeatures:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            60                  Label Len:          48
#   Pred Len:           24                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            256
#   n heads:            8                   e layers:           2
#   d layers:           1                   d FF:               512
#   Moving Avg:         25                  Factor:             3
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       10                  Batch Size:         32
#   Patience:           3                   Learning Rate:      0.0001
#   Des:                NoiseTest_std01     Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# >>>>>>>start training : long_term_forecast_ECL_96_96_TimesNet_custom_ftM_sl60_ll48_pl24_dm256_nh8_el2_dl1_df512_expand2_dc4_fc3_ebtimeF_dtTrue_NoiseTest_std01_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 593
# val 74
# test 170
# Epoch: 1 cost time: 5.733231067657471
# Epoch: 1, Steps: 19 | Train Loss: 0.6831057 Vali Loss: 0.3599211 Test Loss: 2.5537813
# Validation loss decreased (inf --> 0.359921).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 4.419890403747559
# Epoch: 2, Steps: 19 | Train Loss: 0.4786342 Vali Loss: 0.3331472 Test Loss: 2.6496210
# Validation loss decreased (0.359921 --> 0.333147).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 4.429776906967163
# Epoch: 3, Steps: 19 | Train Loss: 0.3904567 Vali Loss: 0.3084723 Test Loss: 2.5616229
# Validation loss decreased (0.333147 --> 0.308472).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 4.4461822509765625
# Epoch: 4, Steps: 19 | Train Loss: 0.3495170 Vali Loss: 0.2767037 Test Loss: 2.7122068
# Validation loss decreased (0.308472 --> 0.276704).  Saving model ...
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 4.428125619888306
# Epoch: 5, Steps: 19 | Train Loss: 0.3196641 Vali Loss: 0.2957585 Test Loss: 2.6342666
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 4.409397840499878
# Epoch: 6, Steps: 19 | Train Loss: 0.3120811 Vali Loss: 0.2822999 Test Loss: 2.9647894
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-06
# Epoch: 7 cost time: 4.398941516876221
# Epoch: 7, Steps: 19 | Train Loss: 0.3046723 Vali Loss: 0.3351946 Test Loss: 2.8208387
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : long_term_forecast_ECL_96_96_TimesNet_custom_ftM_sl60_ll48_pl24_dm256_nh8_el2_dl1_df512_expand2_dc4_fc3_ebtimeF_dtTrue_NoiseTest_std01_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 170
# test shape: (170, 24, 7) (170, 24, 7)
# test shape: (170, 24, 7) (170, 24, 7)
# mse:2.2251369953155518, mae:0.9649078845977783, dtw:Not calculated

# %% [markdown]
# # std of noise = 0.5

# %%
# !python -u run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/illness/ \
  --data_path national_illness.csv \
  --model_id ECL_96_96 \
  --model TimesNet \
  --data custom \
  --features M \
  --seq_len 60 \
  --label_len 48 \
  --pred_len 24 \
  --e_layers 2 \
  --d_layers 1 \
  --factor 3 \
  --enc_in 7 \
  --dec_in 7 \
  --c_out 7 \
  --d_model 256 \
  --d_ff 512 \
  --top_k 5 \
  --des 'NoiseTest_std05'\
  --add_noise \
  --noise_std 0.5\
  --itr 1
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ECL_96_96           Model:              TimesNet
#
# Data Loader
#   Data:               custom              Root Path:          ./dataset/illness/
#   Data Path:          national_illness.csvFeatures:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            60                  Label Len:          48
#   Pred Len:           24                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            256
#   n heads:            8                   e layers:           2
#   d layers:           1                   d FF:               512
#   Moving Avg:         25                  Factor:             3
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       10                  Batch Size:         32
#   Patience:           3                   Learning Rate:      0.0001
#   Des:                NoiseTest_std05     Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# >>>>>>>start training : long_term_forecast_ECL_96_96_TimesNet_custom_ftM_sl60_ll48_pl24_dm256_nh8_el2_dl1_df512_expand2_dc4_fc3_ebtimeF_dtTrue_NoiseTest_std05_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 593
# val 74
# test 170
# Epoch: 1 cost time: 5.6410322189331055
# Epoch: 1, Steps: 19 | Train Loss: 0.6820472 Vali Loss: 0.3454568 Test Loss: 2.6121352
# Validation loss decreased (inf --> 0.345457).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 4.413080453872681
# Epoch: 2, Steps: 19 | Train Loss: 0.4796336 Vali Loss: 0.3365525 Test Loss: 2.3693476
# Validation loss decreased (0.345457 --> 0.336552).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 4.392126083374023
# Epoch: 3, Steps: 19 | Train Loss: 0.3960228 Vali Loss: 0.2965775 Test Loss: 2.3304260
# Validation loss decreased (0.336552 --> 0.296578).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 4.4241063594818115
# Epoch: 4, Steps: 19 | Train Loss: 0.3571744 Vali Loss: 0.2715282 Test Loss: 2.3761721
# Validation loss decreased (0.296578 --> 0.271528).  Saving model ...
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 4.43251895904541
# Epoch: 5, Steps: 19 | Train Loss: 0.3300611 Vali Loss: 0.3007799 Test Loss: 2.3662689
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 4.393900156021118
# Epoch: 6, Steps: 19 | Train Loss: 0.3213727 Vali Loss: 0.2770828 Test Loss: 2.4559984
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-06
# Epoch: 7 cost time: 4.397042512893677
# Epoch: 7, Steps: 19 | Train Loss: 0.3115565 Vali Loss: 0.3224438 Test Loss: 2.3643141
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : long_term_forecast_ECL_96_96_TimesNet_custom_ftM_sl60_ll48_pl24_dm256_nh8_el2_dl1_df512_expand2_dc4_fc3_ebtimeF_dtTrue_NoiseTest_std05_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 170
# test shape: (170, 24, 7) (170, 24, 7)
# test shape: (170, 24, 7) (170, 24, 7)
# mse:2.200654983520508, mae:0.9840978980064392, dtw:Not calculated

# %% [markdown]
# # std of noise = 1

# %%
# !python -u run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/illness/ \
  --data_path national_illness.csv \
  --model_id ECL_96_96 \
  --model TimesNet \
  --data custom \
  --features M \
  --seq_len 60 \
  --label_len 48 \
  --pred_len 24 \
  --e_layers 2 \
  --d_layers 1 \
  --factor 3 \
  --enc_in 7 \
  --dec_in 7 \
  --c_out 7 \
  --d_model 256 \
  --d_ff 512 \
  --top_k 5 \
  --des 'NoiseTest_std05'\
  --add_noise \
  --noise_std 1\
  --itr 1
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ECL_96_96           Model:              TimesNet
#
# Data Loader
#   Data:               custom              Root Path:          ./dataset/illness/
#   Data Path:          national_illness.csvFeatures:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            60                  Label Len:          48
#   Pred Len:           24                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            256
#   n heads:            8                   e layers:           2
#   d layers:           1                   d FF:               512
#   Moving Avg:         25                  Factor:             3
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       10                  Batch Size:         32
#   Patience:           3                   Learning Rate:      0.0001
#   Des:                NoiseTest_std05     Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# >>>>>>>start training : long_term_forecast_ECL_96_96_TimesNet_custom_ftM_sl60_ll48_pl24_dm256_nh8_el2_dl1_df512_expand2_dc4_fc3_ebtimeF_dtTrue_NoiseTest_std05_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 593
# val 74
# test 170
# Epoch: 1 cost time: 5.61089015007019
# Epoch: 1, Steps: 19 | Train Loss: 0.7262361 Vali Loss: 0.3811603 Test Loss: 3.0184307
# Validation loss decreased (inf --> 0.381160).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 4.38500714302063
# Epoch: 2, Steps: 19 | Train Loss: 0.5037268 Vali Loss: 0.3453755 Test Loss: 2.4250340
# Validation loss decreased (0.381160 --> 0.345376).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 4.384577512741089
# Epoch: 3, Steps: 19 | Train Loss: 0.4158201 Vali Loss: 0.2993148 Test Loss: 2.3211462
# Validation loss decreased (0.345376 --> 0.299315).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 4.361678123474121
# Epoch: 4, Steps: 19 | Train Loss: 0.3802838 Vali Loss: 0.2625560 Test Loss: 2.3599403
# Validation loss decreased (0.299315 --> 0.262556).  Saving model ...
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 4.3718342781066895
# Epoch: 5, Steps: 19 | Train Loss: 0.3571140 Vali Loss: 0.3000137 Test Loss: 2.3572264
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 4.327774286270142
# Epoch: 6, Steps: 19 | Train Loss: 0.3448588 Vali Loss: 0.2745368 Test Loss: 2.3878391
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-06
# Epoch: 7 cost time: 4.328557014465332
# Epoch: 7, Steps: 19 | Train Loss: 0.3443989 Vali Loss: 0.3154764 Test Loss: 2.3079240
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : long_term_forecast_ECL_96_96_TimesNet_custom_ftM_sl60_ll48_pl24_dm256_nh8_el2_dl1_df512_expand2_dc4_fc3_ebtimeF_dtTrue_NoiseTest_std05_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 170
# test shape: (170, 24, 7) (170, 24, 7)
# test shape: (170, 24, 7) (170, 24, 7)
# mse:2.4143054485321045, mae:1.0660111904144287, dtw:Not calculated

# %% [markdown]
# # std of noise = 0.01

# %%
# !python -u run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/illness/ \
  --data_path national_illness.csv \
  --model_id ECL_96_96 \
  --model TimesNet \
  --data custom \
  --features M \
  --seq_len 60 \
  --label_len 48 \
  --pred_len 24 \
  --e_layers 2 \
  --d_layers 1 \
  --factor 3 \
  --enc_in 7 \
  --dec_in 7 \
  --c_out 7 \
  --d_model 256 \
  --d_ff 512 \
  --top_k 5 \
  --des 'NoiseTest_std001_uniform'\
  --itr 1\
  --noise_std 0.01\
  --noise_type uniform
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ECL_96_96           Model:              TimesNet
#
# Data Loader
#   Data:               custom              Root Path:          ./dataset/illness/
#   Data Path:          national_illness.csvFeatures:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            60                  Label Len:          48
#   Pred Len:           24                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            256
#   n heads:            8                   e layers:           2
#   d layers:           1                   d FF:               512
#   Moving Avg:         25                  Factor:             3
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       10                  Batch Size:         32
#   Patience:           3                   Learning Rate:      0.0001
#   Des:                NoiseTest_std001_uniformLoss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# >>>>>>>start training : long_term_forecast_ECL_96_96_TimesNet_custom_ftM_sl60_ll48_pl24_dm256_nh8_el2_dl1_df512_expand2_dc4_fc3_ebtimeF_dtTrue_NoiseTest_std001_uniform_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 593
# val 74
# test 170
# Epoch: 1 cost time: 5.677659749984741
# Epoch: 1, Steps: 19 | Train Loss: 0.6893893 Vali Loss: 0.3575294 Test Loss: 2.6204586
# Validation loss decreased (inf --> 0.357529).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 4.420024633407593
# Epoch: 2, Steps: 19 | Train Loss: 0.4809290 Vali Loss: 0.3328673 Test Loss: 2.7744815
# Validation loss decreased (0.357529 --> 0.332867).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 4.405660390853882
# Epoch: 3, Steps: 19 | Train Loss: 0.3952466 Vali Loss: 0.3112910 Test Loss: 2.5590391
# Validation loss decreased (0.332867 --> 0.311291).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 4.408318758010864
# Epoch: 4, Steps: 19 | Train Loss: 0.3552491 Vali Loss: 0.2772477 Test Loss: 2.8003769
# Validation loss decreased (0.311291 --> 0.277248).  Saving model ...
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 4.382074594497681
# Epoch: 5, Steps: 19 | Train Loss: 0.3186142 Vali Loss: 0.2794870 Test Loss: 2.7764270
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 4.38177227973938
# Epoch: 6, Steps: 19 | Train Loss: 0.3135583 Vali Loss: 0.2745975 Test Loss: 3.0093040
# Validation loss decreased (0.277248 --> 0.274597).  Saving model ...
# Updating learning rate to 3.125e-06
# Epoch: 7 cost time: 4.385510683059692
# Epoch: 7, Steps: 19 | Train Loss: 0.3066273 Vali Loss: 0.3321414 Test Loss: 2.9044800
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.5625e-06
# Epoch: 8 cost time: 4.348132610321045
# Epoch: 8, Steps: 19 | Train Loss: 0.3017934 Vali Loss: 0.2823142 Test Loss: 2.9417617
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 7.8125e-07
# Epoch: 9 cost time: 4.3748297691345215
# Epoch: 9, Steps: 19 | Train Loss: 0.3058206 Vali Loss: 0.2753448 Test Loss: 2.9467442
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : long_term_forecast_ECL_96_96_TimesNet_custom_ftM_sl60_ll48_pl24_dm256_nh8_el2_dl1_df512_expand2_dc4_fc3_ebtimeF_dtTrue_NoiseTest_std001_uniform_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 170
# test shape: (170, 24, 7) (170, 24, 7)
# test shape: (170, 24, 7) (170, 24, 7)
# mse:2.3151752948760986, mae:0.9773611426353455, dtw:Not calculated
