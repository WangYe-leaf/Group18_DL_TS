# %%
# %cd Time-Series-Library
# !pwd
# Out:
# /datasets/_deepnote_work/Time-Series-Library
# /datasets/_deepnote_work/Time-Series-Library

# %%
# !mkdir -p result/PatchTST_electricity_96
# !mkdir -p result/PatchTST_electricity_192
# !mkdir -p result/PatchTST_electricity_336
# !mkdir -p result/PatchTST_electricity_720

# %%
# !python run.py \
--is_training 1 \
--task_name long_term_forecast \
--model_id PatchTST_electricity_96 \
--model PatchTST \
--data custom \
--root_path ./dataset/Electricity \
--data_path electricity.csv \
--features M \
--seq_len 96 \
--pred_len 96 \
--e_layers 2 \
--d_layers 1 \
--enc_in 321 \
--d_model 256 \
--learning_rate 0.001 \
--train_epochs 50 \
--batch_size 16 \
--patience 10 \
--checkpoints ./result/PatchTST_electricity_96 \
--des benchmark_patchtst \
2>&1 | tee result/PatchTST_electricity_96/train_log.txt
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           PatchTST_electricity_96Model:              PatchTST
#
# Data Loader
#   Data:               custom              Root Path:          ./dataset/Electricity
#   Data Path:          electricity.csv     Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./result/PatchTST_electricity_96
#
# Forecasting Task
#   Seq Len:            96                  Label Len:          48
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             321                 Dec In:             7
#   C Out:              7                   d model:            256
#   n heads:            8                   e layers:           2
# ...

# %%
# !python run.py \
--is_training 1 \
--task_name long_term_forecast \
--model_id PatchTST_electricity_192 \
--model PatchTST \
--data custom \
--root_path ./dataset/Electricity \
--data_path electricity.csv \
--features M \
--seq_len 96 \
--pred_len 192 \
--e_layers 2 \
--d_layers 1 \
--enc_in 321 \
--d_model 256 \
--learning_rate 0.001 \
--train_epochs 50 \
--batch_size 16 \
--patience 10 \
--checkpoints ./result/PatchTST_electricity_192 \
--des benchmark_patchtst \
2>&1 | tee result/PatchTST_electricity_192/train_log.txt
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           PatchTST_electricity_192Model:              PatchTST
#
# Data Loader
#   Data:               custom              Root Path:          ./dataset/Electricity
#   Data Path:          electricity.csv     Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./result/PatchTST_electricity_192
#
# Forecasting Task
#   Seq Len:            96                  Label Len:          48
#   Pred Len:           192                 Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             321                 Dec In:             7
#   C Out:              7                   d model:            256
#   n heads:            8                   e layers:           2
# ...

# %%
# !python run.py \
--is_training 1 \
--task_name long_term_forecast \
--model_id PatchTST_electricity_336 \
--model PatchTST \
--data custom \
--root_path ./dataset/Electricity \
--data_path electricity.csv \
--features M \
--seq_len 96 \
--pred_len 336 \
--e_layers 2 \
--d_layers 1 \
--enc_in 321 \
--d_model 256 \
--learning_rate 0.001 \
--train_epochs 50 \
--batch_size 16 \
--patience 10 \
--checkpoints ./result/PatchTST_electricity_336 \
--des benchmark_patchtst \
2>&1 | tee result/PatchTST_electricity_336/train_log.txt
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           PatchTST_electricity_336Model:              PatchTST
#
# Data Loader
#   Data:               custom              Root Path:          ./dataset/Electricity
#   Data Path:          electricity.csv     Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./result/PatchTST_electricity_336
#
# Forecasting Task
#   Seq Len:            96                  Label Len:          48
#   Pred Len:           336                 Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             321                 Dec In:             7
#   C Out:              7                   d model:            256
#   n heads:            8                   e layers:           2
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=25aca1a4-5304-4528-85ec-154f53dfeb1c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
